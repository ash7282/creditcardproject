# %%
import pandas as pd
# Out:
# C:\Users\AshEdito\AppData\Local\Temp\ipykernel_12200\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
#pd.read_csv('notebooks\\data\\UCI_Credit_Card.csv')
data=pd.read_csv('\\PYTHON CODING\\INTERSHIP PROJECT\\CREDIT CARD DEFAULT PREDICTION PROJECT\\notebooks\\data\\UCI_Credit_Card.csv')

# %%
data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df=data.copy()

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
df['EDUCATION'].unique()
# Out:
# array([2, 1, 3, 5, 4, 6, 0], dtype=int64)

# %%
df['EDUCATION'].replace(to_replace=[0,5,6],value=4,inplace=True)
# Out:
# C:\Users\AshEdito\AppData\Local\Temp\ipykernel_20036\3476788230.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['EDUCATION'].replace(to_replace=[0,5,6],value=4,inplace=True)

# %%
df['EDUCATION'].unique()
# Out:
# array([2, 1, 3, 4], dtype=int64)

# %%
df['SEX'].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
df['MARRIAGE'].unique()
# Out:
# array([1, 2, 3, 0], dtype=int64)

# %%
df['MARRIAGE'].replace(to_replace=[0],value=3,inplace=True)
# Out:
# C:\Users\AshEdito\AppData\Local\Temp\ipykernel_20036\3975916943.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['MARRIAGE'].replace(to_replace=[0],value=3,inplace=True)

# %%
df['MARRIAGE'].value_counts()
# Out:
# MARRIAGE
# 2    15964
# 1    13659
# 3      377
# Name: count, dtype: int64

# %%
df.mean()
# Out:
# ID                             15000.500000
# LIMIT_BAL                     167484.322667
# SEX                                1.603733
# EDUCATION                          1.842267
# MARRIAGE                           1.557267
# AGE                               35.485500
# PAY_0                             -0.016700
# PAY_2                             -0.133767
# PAY_3                             -0.166200
# PAY_4                             -0.220667
# PAY_5                             -0.266200
# PAY_6                             -0.291100
# BILL_AMT1                      51223.330900
# BILL_AMT2                      49179.075167
# BILL_AMT3                      47013.154800
# BILL_AMT4                      43262.948967
# BILL_AMT5                      40311.400967
# BILL_AMT6                      38871.760400
# PAY_AMT1                        5663.580500
# PAY_AMT2                        5921.163500
# PAY_AMT3                        5225.681500
# ...

# %%
df.median()
# Out:
# ID                             15000.5
# LIMIT_BAL                     140000.0
# SEX                                2.0
# EDUCATION                          2.0
# MARRIAGE                           2.0
# AGE                               34.0
# PAY_0                              0.0
# PAY_2                              0.0
# PAY_3                              0.0
# PAY_4                              0.0
# PAY_5                              0.0
# PAY_6                              0.0
# BILL_AMT1                      22381.5
# BILL_AMT2                      21200.0
# BILL_AMT3                      20088.5
# BILL_AMT4                      19052.0
# BILL_AMT5                      18104.5
# BILL_AMT6                      17071.0
# PAY_AMT1                        2100.0
# PAY_AMT2                        2009.0
# PAY_AMT3                        1800.0
# PAY_AMT4                        1500.0
# PAY_AMT5                        1500.0
# PAY_AMT6                        1500.0
# ...

# %%
df.mode()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    50000.0  2.0        2.0       2.0  29.0    0.0    0.0    0.0
# 1          2        NaN  NaN        NaN       NaN   NaN    NaN    NaN    NaN
# 2          3        NaN  NaN        NaN       NaN   NaN    NaN    NaN    NaN
# 3          4        NaN  NaN        NaN       NaN   NaN    NaN    NaN    NaN
# 4          5        NaN  NaN        NaN       NaN   NaN    NaN    NaN    NaN
# ...      ...        ...  ...        ...       ...   ...    ...    ...    ...
# 29995  29996        NaN  NaN        NaN       NaN   NaN    NaN    NaN    NaN
# 29996  29997        NaN  NaN        NaN       NaN   NaN    NaN    NaN    NaN
# 29997  29998        NaN  NaN        NaN       NaN   NaN    NaN    NaN    NaN
# 29998  29999        NaN  NaN        NaN       NaN   NaN    NaN    NaN    NaN
# 29999  30000        NaN  NaN        NaN       NaN   NaN    NaN    NaN    NaN
#
# ...

# %%
df['default.payment.next.month'].value_counts()
# Out:
# default.payment.next.month
# 0    23364
# 1     6636
# Name: count, dtype: int64

# %%
df=df.drop('ID',axis=1)

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
df.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667      1.603733      1.842267      1.557267     35.485500
# std     129747.661567      0.489129      0.744494      0.521405      9.217904
# min      10000.000000      1.000000      1.000000      1.000000     21.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      4.000000      3.000000     79.000000
#
#               PAY_0         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.016700     -0.133767     -0.166200     -0.220667     -0.266200
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
cols=df.columns
for col in cols:
    plt.hist(data=df,x=col)
    plt.xlabel(col)
    plt.show()

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month'],
#       dtype='object')

# %%
df.boxplot(column='PAY_AMT6')
# Out:
# <Axes: >

# %%
numerical_cols=df.columns[df.dtypes !='object']

# %%
numerical_cols
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month'],
#       dtype='object')

# %%
categorical_cols=df.columns[df.dtypes =='object']

# %%
categorical_cols
# Out:
# Index([], dtype='object')

# %%
df.plot(kind='scatter', x='PAY_AMT4', y='PAY_AMT5')
# Out:
# <Axes: xlabel='PAY_AMT4', ylabel='PAY_AMT5'>

# %%
for i in numerical_cols:
    df.plot(kind='scatter',x=[i],y=[numerical_cols])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 for i in numerical_cols:
# ----> 2     df.plot(kind='scatter',x=[i],y=[numerical_cols])
#
# File d:\PYTHON CODING\INTERSHIP PROJECT\CREDIT CARD DEFAULT PREDICTION PROJECT\creditcard\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     973 if kind in self._dataframe_kinds:
#     974     if isinstance(data, ABCDataFrame):
# --> 975         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     976     else:
#     977         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File d:\PYTHON CODING\INTERSHIP PROJECT\CREDIT CARD DEFAULT PREDICTION PROJECT\creditcard\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...
