# %%
import pandas as pd
# Out:
# C:\Users\AshEdito\AppData\Local\Temp\ipykernel_16980\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data=pd.read_csv('\\PYTHON CODING\\INTERSHIP PROJECT\\CREDIT CARD DEFAULT PREDICTION PROJECT\\notebooks\\data\\UCI_Credit_Card.csv')

# %%
data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df=data.copy()

# %%
df=df.drop('ID',axis=1)

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0    20000.0    2          2         1   24      2      2     -1     -1
# 1   120000.0    2          2         2   26     -1      2      0      0
# 2    90000.0    2          2         2   34      0      0      0      0
# 3    50000.0    2          2         1   37      0      0      0      0
# 4    50000.0    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1      0  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2      0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3      0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4      0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
numerical_cols=df.columns[df.dtypes !='object']

# %%
numerical_cols
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month'],
#       dtype='object')

# %%
df.dtypes
# Out:
# LIMIT_BAL                     float64
# SEX                             int64
# EDUCATION                       int64
# MARRIAGE                        int64
# AGE                             int64
# PAY_0                           int64
# PAY_2                           int64
# PAY_3                           int64
# PAY_4                           int64
# PAY_5                           int64
# PAY_6                           int64
# BILL_AMT1                     float64
# BILL_AMT2                     float64
# BILL_AMT3                     float64
# BILL_AMT4                     float64
# BILL_AMT5                     float64
# BILL_AMT6                     float64
# PAY_AMT1                      float64
# PAY_AMT2                      float64
# PAY_AMT3                      float64
# PAY_AMT4                      float64
# PAY_AMT5                      float64
# PAY_AMT6                      float64
# default.payment.next.month      int64
# dtype: object

# %%
X=df.drop('default.payment.next.month',axis=1)
y=df['default.payment.next.month']

# %%
X
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0        20000.0    2          2         1   24      2      2     -1     -1
# 1       120000.0    2          2         2   26     -1      2      0      0
# 2        90000.0    2          2         2   34      0      0      0      0
# 3        50000.0    2          2         1   37      0      0      0      0
# 4        50000.0    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995   220000.0    1          3         1   39      0      0      0      0
# 29996   150000.0    1          3         2   43     -1     -1     -1     -1
# 29997    30000.0    1          2         2   37      4      3      2     -1
# 29998    80000.0    1          3         1   41      1     -1      0      0
# 29999    50000.0    1          2         1   46      0      0      0      0
#
# ...

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 29995    0
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: default.payment.next.month, Length: 30000, dtype: int64

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip list
# Out:
# Package           Version
# ----------------- -----------
# asttokens         2.4.1
# blinker           1.7.0
# click             8.1.7
# colorama          0.4.6
# comm              0.2.1
# contourpy         1.2.0
# cycler            0.12.1
# debugpy           1.8.1
# decorator         5.1.1
# executing         2.0.1
# Flask             3.0.2
# fonttools         4.49.0
# ipykernel         6.29.2
# ipython           8.21.0
# itsdangerous      2.1.2
# jedi              0.19.1
# Jinja2            3.1.3
# joblib            1.3.2
# jupyter_client    8.6.0
# jupyter_core      5.7.1
# kiwisolver        1.4.5
# MarkupSafe        2.1.5
# matplotlib        3.8.3
# matplotlib-inline 0.1.6
# nest-asyncio      1.6.0
# numpy             1.26.4
# packaging         23.2
# pandas            2.2.0
# parso             0.8.3
# pillow            10.2.0
# pip               23.2.1
# platformdirs      4.2.0
# prompt-toolkit    3.0.43
# psutil            5.9.8
# pure-eval         0.2.2
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression

# %%
num_pipeline=Pipeline(
    steps=[
        ('imputer',SimpleImputer(strategy='median')),
        ('scaler',StandardScaler())
    ]
)
preprocessor=ColumnTransformer([
    ('num_pipeline',num_pipeline,numerical_cols)
])

# %%
num_pipeline
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('scaler', StandardScaler())])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month'],
#       dtype='object'))])

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train.shape
# Out:
# (21000, 23)

# %%
y_train.shape
# Out:
# (21000,)

# %%
X_test.shape
# Out:
# (9000, 23)

# %%
y_test.shape
# Out:
# (9000,)

# %%
scaler =StandardScaler()
scaler.fit(X_train)

X_train =scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.56391448,  0.80648893, -1.07681763, ..., -0.30370385,
#         -0.30669703, -0.29550752],
#        [-0.90610925,  0.80648893, -1.07681763, ...,  0.3050678 ,
#         -0.26502896, -0.12727157],
#        [-0.90610925,  0.80648893,  0.18648797, ..., -0.17934316,
#         -0.08573001, -0.29550752],
#        ...,
#        [-0.90610925, -1.23994262, -1.07681763, ..., -0.30370385,
#         -0.30669703, -0.29550752],
#        [-0.75136991,  0.80648893,  0.18648797, ..., -0.22923637,
#         -0.30669703, -0.2277615 ],
#        [-0.05504288,  0.80648893,  0.18648797, ..., -0.20131106,
#          0.58979774, -0.210825  ]])

# %%
X_test
# Out:
# array([[-1.06084859, -1.23994262,  0.18648797, ..., -0.2106195 ,
#         -0.21199688, -0.18259749],
#        [-0.13241255,  0.80648893, -1.07681763, ..., -0.139441  ,
#         -0.13819389, -0.14482908],
#        [-0.75136991,  0.80648893,  1.44979356, ..., -0.15241075,
#         -0.14886344, -0.15132141],
#        ...,
#        [-0.59663057, -1.23994262,  0.18648797, ..., -0.23469732,
#         -0.23699772, -0.23097944],
#        [ 0.40917514,  0.80648893,  0.18648797, ...,  0.02966224,
#          0.05701469,  0.00912376],
#        [ 0.64128415,  0.80648893, -1.07681763, ..., -0.03617943,
#         -0.25518015,  0.22190272]])

# %%
leg=LinearRegression()
leg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
leg.score(X_train,y_train)
# Out:
# 0.12728008213511477

# %%
leg.coef_
# Out:
# array([-0.01251013, -0.00725301, -0.01145199, -0.01207893,  0.01445458,
#         0.10777842,  0.02579322,  0.01562378,  0.00542605,  0.00143465,
#         0.00413289, -0.04851965,  0.01725565,  0.00523534, -0.00895033,
#        -0.00790931,  0.00859245, -0.01087926, -0.00467177,  0.00128892,
#        -0.00126931, -0.00539764, -0.00263549])

# %%
X_train
# Out:
# array([[ 0.56391448,  0.80648893, -1.07681763, ..., -0.30370385,
#         -0.30669703, -0.29550752],
#        [-0.90610925,  0.80648893, -1.07681763, ...,  0.3050678 ,
#         -0.26502896, -0.12727157],
#        [-0.90610925,  0.80648893,  0.18648797, ..., -0.17934316,
#         -0.08573001, -0.29550752],
#        ...,
#        [-0.90610925, -1.23994262, -1.07681763, ..., -0.30370385,
#         -0.30669703, -0.29550752],
#        [-0.75136991,  0.80648893,  0.18648797, ..., -0.22923637,
#         -0.30669703, -0.2277615 ],
#        [-0.05504288,  0.80648893,  0.18648797, ..., -0.20131106,
#          0.58979774, -0.210825  ]])

# %%
import numpy as np 
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet,LogisticRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc, classification_report
from sklearn.model_selection import train_test_split, cross_validate, cross_val_score, GridSearchCV

# %%
import numpy as np
def evaluate_model(true,predicted):
    mae=mean_absolute_error(true,predicted)
    mse=mean_squared_error(true,predicted)
    rmse=np.sqrt(mean_squared_error(true,predicted))
    r2_square=r2_score(true,predicted)
    return mae,rmse,r2_square

# %%
models={
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'Elasticnet':ElasticNet()
}
trained_model_list=[]
model_list=[]
r2_list=[]

for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    mae,rmse,r2_square=evaluate_model(y_test,y_pred)
    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])
    print('model Training Performance')
    print('RMSE',rmse)
    print('MAE',mae)
    print('R2 score',r2_square*100)
    r2_list.append(r2_square)

    print('='*35)
    print('\n')
# Out:
# LinearRegression
# model Training Performance
# RMSE 0.38821507218042756
# MAE 0.30692663002771836
# R2 score 11.528972027826267
# ...
#
#
# Lasso
# model Training Performance
# RMSE 0.41276448311176017
# MAE 0.34346074074074073
# R2 score -0.014030612244919638
# ...
#
#
# Ridge
# model Training Performance
# RMSE 0.38821487219413836
# MAE 0.3069268512178869
# R2 score 11.529063178269915
# ...
#
#
# Elasticnet
# model Training Performance
# RMSE 0.41276448311176017
# MAE 0.34346074074074073
# R2 score -0.014030612244919638
# ...

# %%
knn= KNeighborsClassifier(n_neighbors=6,weights='distance')
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6, weights='distance')

# %%
knn_y_pred_train =knn.predict(X_train)

knn_tree_y_pred_test=knn.predict(X_test)

# %%
knn_y_pred_train
# Out:
# array([1, 0, 0, ..., 0, 1, 1], dtype=int64)

# %%
knn_tree_y_pred_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
print(' untuned k nearest Neighbors model')
#Compute the F1 score, also known as balanced F-score or F-measure.
print("Training F1 Score: ", f1_score(y_train,knn_y_pred_train))

print('Testing F1 score: ', f1_score(y_test, knn_tree_y_pred_test))
# Out:
#  untuned k nearest Neighbors model
# Training F1 Score:  0.9989295654035538
# Testing F1 score:  0.411214953271028

# %%
k_near = KNeighborsClassifier(weights='distance')

# %%
k_param_dict = {'n_neighbors': range(3,5,7)} # creating parameter to test

# %%
# create the instance of gridsearch using metrics our scoring
grid_k_neighbors = GridSearchCV(k_near, k_param_dict, cv=5,scoring='f1',verbose=1)

# %%
#fit the grid search to our data
grid_k_neighbors.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(weights='distance'),
#              param_grid={'n_neighbors': range(3, 5, 7)}, scoring='f1',
#              verbose=1)

# %%
print('F1 score :', grid_k_neighbors.best_score_)

# check dictionary showing best hyperparameters

print('Best Hyperparameter:', grid_k_neighbors.best_params_)

# actual model object fit with those best parameters
# also shows default parameter that did not specify

print('model boject with best parametere: ')
print(grid_k_neighbors.best_estimator_)
# Out:
# F1 score : 0.4120544527935916
# Best Hyperparameter: {'n_neighbors': 3}
# model boject with best parametere:
# KNeighborsClassifier(n_neighbors=3, weights='distance')

# %%
logreg=LogisticRegression(C=1e9,class_weight='balanced')
logreg.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1000000000.0, class_weight='balanced')

# %%
logreg_y_pred_train=logreg.predict(X_train)
logreg_y_pred_test=logreg.predict(X_test)

# %%
print('Untuned Logistic Regression Model')
print("Training F1 Score: ", f1_score(y_train, logreg_y_pred_train))
print("Testing F1 Score: ", f1_score(y_test, logreg_y_pred_test))
# Out:
# Untuned Logistic Regression Model
# Training F1 Score:  0.48434740728848935
# Testing F1 Score:  0.4765164479939152

# %%
y_pred_prob = logreg.predict_proba(X_test)[:, 1]

# %%
import matplotlib.pyplot as plt
# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve for Logisitic Regression')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.grid(True)

# %%
# y_true = y_test (ground truth/ correct target values)
# y_pred = logreg_y_pred_test (estimated targets as returned by classifier)

confusion =confusion_matrix(y_test, logreg_y_pred_test)
TN = confusion[0, 0]
FP = confusion[0, 1]
FN = confusion[1, 0]
TP = confusion[1, 1]

# %%
confusion
# Out:
# array([[4994, 2046],
#        [ 707, 1253]], dtype=int64)

# %%
print((TP + TN) / float(TP + TN + FP + FN))
# Out:
# 0.6941111111111111

# %%
print('accuracy:', accuracy_score(y_test, logreg_y_pred_test))
print('precision:', precision_score(y_test, logreg_y_pred_test))
print('recall:',recall_score(y_test, logreg_y_pred_test))
print('specificity:', TN / float(TN + FP))
print('f1 score:',f1_score(y_test, logreg_y_pred_test))
# Out:
# accuracy: 0.6941111111111111
# precision: 0.37981206426189756
# recall: 0.6392857142857142
# specificity: 0.709375
# f1 score: 0.4765164479939152

# %%
features=df.drop('default.payment.next.month',axis=1)
target=df['default.payment.next.month']

# %%
# best_model = pickle.dumps(grid_log.best_estimator_) 
best_model = LogisticRegression(C=3, class_weight='balanced', random_state=6)

# %%
best_model = best_model.fit(features,target)
# Out:
# d:\PYTHON CODING\INTERSHIP PROJECT\CREDIT CARD DEFAULT PREDICTION PROJECT\creditcard\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
best_model
# Out:
# LogisticRegression(C=3, class_weight='balanced', random_state=6)

# %%
features
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0        20000.0    2          2         1   24      2      2     -1     -1
# 1       120000.0    2          2         2   26     -1      2      0      0
# 2        90000.0    2          2         2   34      0      0      0      0
# 3        50000.0    2          2         1   37      0      0      0      0
# 4        50000.0    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995   220000.0    1          3         1   39      0      0      0      0
# 29996   150000.0    1          3         2   43     -1     -1     -1     -1
# 29997    30000.0    1          2         2   37      4      3      2     -1
# 29998    80000.0    1          3         1   41      1     -1      0      0
# 29999    50000.0    1          2         1   46      0      0      0      0
#
# ...

# %%
best_model.coef_
# Out:
# array([[-1.86095870e-06,  2.27910342e-04,  3.35975167e-04,
#          2.26835297e-04,  6.47748065e-03,  7.12592284e-04,
#          5.55225442e-04,  4.81520350e-04,  4.17771062e-04,
#          3.64095577e-04,  3.22559402e-04, -1.05681456e-05,
#          1.21511736e-05, -1.41842424e-07, -8.02908452e-07,
#         -2.18733191e-06,  6.56811791e-06, -2.14560152e-05,
#         -1.43435857e-05, -2.09996265e-06, -4.59191525e-06,
#         -1.36095813e-05, -5.89294540e-06]])

# %%
from sklearn.inspection import permutation_importance

model_fi = permutation_importance(best_model, X, y)

# %%
model_fi['importances_mean']
# Out:
# array([-5.44000000e-03, -1.33333333e-05,  2.00000000e-05, -1.33333333e-05,
#         5.26000000e-03,  6.66666667e-05,  5.33333333e-05, -1.20000000e-04,
#        -8.66666667e-05, -1.40000000e-04, -2.66666667e-05,  2.87000000e-02,
#         1.66133333e-02, -7.80000000e-04, -3.08000000e-03, -4.10666667e-03,
#        -1.85333333e-03,  5.20000000e-04, -7.35333333e-03, -2.44000000e-03,
#        -2.36000000e-03, -2.48666667e-03, -6.51333333e-03])

# %%
print(best_model.LogisticRegression)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 print(best_model.LogisticRegression)
#
# AttributeError: 'LogisticRegression' object has no attribute 'LogisticRegression'

# %%
feat_importances = pd.Series(best_model.coef_,index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 feat_importances = pd.Series(best_model.coef_)
#       2 feat_importances.nlargest(10).plot(kind='barh')
#       3 plt.show()
#
# File d:\PYTHON CODING\INTERSHIP PROJECT\CREDIT CARD DEFAULT PREDICTION PROJECT\creditcard\Lib\site-packages\pandas\core\series.py:583, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     581         data = data.copy()
#     582 else:
# --> 583     data = sanitize_array(data, index, dtype, copy)
#     585     manager = _get_option("mode.data_manager", silent=True)
#     586     if manager == "block":
#
# File d:\PYTHON CODING\INTERSHIP PROJECT\CREDIT CARD DEFAULT PREDICTION PROJECT\creditcard\Lib\site-packages\pandas\core\construction.py:656, in sanitize_array(data, index, dtype, copy, allow_2d)
#     653             subarr = cast(np.ndarray, subarr)
# ...

# %%
coef_df = pd.DataFrame({'Feature': X_train, 'Coefficient': model.coef_[0]})

# Sort by absolute coefficient value (importance)
coef_df['Abs_Coefficient'] = coef_df['Coefficient'].abs()
sorted_coef_df = coef_df.sort_values(by='Abs_Coefficient', ascending=False)

# Print the top N important features
N = 5
top_features = sorted_coef_df.head(N)
print(top_features)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 coef_df = pd.DataFrame({'Feature': X_train, 'Coefficient': model.coef_[0]})
#       3 # Sort by absolute coefficient value (importance)
#       4 coef_df['Abs_Coefficient'] = coef_df['Coefficient'].abs()
#
# File d:\PYTHON CODING\INTERSHIP PROJECT\CREDIT CARD DEFAULT PREDICTION PROJECT\creditcard\Lib\site-packages\pandas\core\frame.py:767, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     761     mgr = self._init_mgr(
#     762         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     763     )
#     765 elif isinstance(data, dict):
#     766     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 767     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     768 elif isinstance(data, ma.MaskedArray):
# ...

# %%
from sklearn.inspection import permutation_importance

# Calculate importance with mean accuracy drop
result = permutation_importance(best_model, df.drop("default.payment.next.month", axis=1), df['default.payment.next.month'], scoring="accuracy")

# Access feature names and importances
feature_names = df.columns.drop('default.payment.next.month')
feature_importance = result.importances_mean

# Print importance in descending order
sorted_importance = sorted(zip(feature_names, feature_importance), key=lambda x: x[1], reverse=True)
for feature, importance in sorted_importance:
    print(f"{feature}: {importance}")
# Out:
# BILL_AMT1: 0.02673333333333332
# BILL_AMT2: 0.01642000000000001
# AGE: 0.005059999999999998
# PAY_AMT1: 0.0004066666666666663
# PAY_2: 5.9999999999993395e-05
# EDUCATION: 1.3333333333331865e-05
# MARRIAGE: 1.3333333333331865e-05
# PAY_0: 1.3333333333331865e-05
# SEX: -1.3333333333331865e-05
# PAY_6: -7.333333333332525e-05
# PAY_4: -7.999999999999118e-05
# PAY_5: -0.00011999999999998679
# PAY_3: -0.0001266666666666527
# BILL_AMT3: -0.0008800000000000141
# BILL_AMT6: -0.0021133333333333447
# PAY_AMT3: -0.0023933333333333363
# BILL_AMT4: -0.003166666666666673
# PAY_AMT5: -0.0032133333333333345
# PAY_AMT4: -0.0034800000000000165
# LIMIT_BAL: -0.004066666666666685
# BILL_AMT5: -0.005566666666666697
# PAY_AMT6: -0.00630666666666666
# PAY_AMT2: -0.006886666666666685

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression

# Load your data
df = pd.read_csv('\\PYTHON CODING\\INTERSHIP PROJECT\\CREDIT CARD DEFAULT PREDICTION PROJECT\\notebooks\\data\\UCI_Credit_Card.csv') 

# Create logistic regression model
model = LogisticRegression(solver="lbfgs")
model.fit(df.drop('default.payment.next.month', axis=1), df['default.payment.next.month'])

# Access coefficients (may require feature scaling)
feature_importance = model.coef_[0]
feature_names = df.columns.drop('default.payment.next.month')  # Assuming "target" is the target column

# Print importance in descending order
sorted_importance = sorted(zip(feature_names, feature_importance), key=lambda x: x[1], reverse=True)
for feature, importance in sorted_importance:
    print(f"{feature}: {importance}")
# Out:
# BILL_AMT2: 5.181978281450958e-06
# BILL_AMT4: 3.0261555317988487e-06
# BILL_AMT6: 2.0429898606750237e-06
# BILL_AMT3: 1.966071463236349e-06
# BILL_AMT5: 1.7354954060625064e-06
# PAY_0: 2.9116338677208294e-07
# PAY_2: 2.2956406090673348e-07
# PAY_3: 1.9978251894294596e-07
# PAY_4: 1.849040705066406e-07
# PAY_5: 1.6659975720281483e-07
# PAY_6: 1.5360764267697187e-07
# SEX: -1.0812282047321902e-07
# MARRIAGE: -1.1688753255563498e-07
# EDUCATION: -1.228521764783552e-07
# AGE: -1.5527411722336075e-06
# PAY_AMT6: -1.8086369043342949e-06
# LIMIT_BAL: -3.9292823214031245e-06
# PAY_AMT5: -6.238225639098638e-06
# PAY_AMT4: -8.342915713698674e-06
# PAY_AMT3: -8.731842216731047e-06
# BILL_AMT1: -9.510778392725796e-06
# PAY_AMT2: -2.1568095551647558e-05
# ID: -2.6290595646966894e-05
# PAY_AMT1: -3.244332235707474e-05
# ...
